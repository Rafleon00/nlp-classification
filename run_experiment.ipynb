# %% [markdown]
# ## NLP Task
#
# ### Objective:
# Build a model that distinguish between houses and apartments based on the information contained in the dataset.
#
# ### Important:
# Automatically run on CPU/GPU/TPU depending on environment

# %% [markdown]
# ### 1. Install dependencies
# - Clone repo
# - cd to nlp-classification folder
# - Install requirements

# %%
# !git clone https://github.com/ralvf/nlp-classification
# %cd nlp-classification/
# Out:
# Cloning into 'nlp-classification'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 12 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (12/12), done.
# /content/nlp-classification

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 585 kB 7.6 MB/s
# ...
#      |████████████████████████████████| 85 kB 4.6 MB/s
# ...
#      |████████████████████████████████| 3.5 MB 50.3 MB/s
# ...
#      |████████████████████████████████| 419 kB 68.5 MB/s
# ...
#      |████████████████████████████████| 596 kB 54.7 MB/s
# ...
#      |████████████████████████████████| 141 kB 69.7 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 63.7 MB/s
# ...
#      |████████████████████████████████| 101 kB 12.8 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 53.6 MB/s
# ...
#      |████████████████████████████████| 880 kB 71.2 MB/s
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=bb3f8eb8994d3b848896a92ec600267dc418af1a489cc910bdfbc5d19156754e
#   Stored in directory: /root/.cache/pip/wheels/bf/06/fb/d59c1e5bd1dac7f6cf61ec0036cc3a10ab8fecaa6b2c3d3ee9
# ...

# %% [markdown]
# ### 2. Run nlp_classification.py

# %%
# !python nlp_classifier.py --num_workers=2 --batch_size=32 --max_epochs=10
# Out:
# Global seed set to 10
# Downloading: 100% 571/571 [00:00<00:00, 421kB/s]
# Downloading: 100% 418M/418M [00:06<00:00, 70.7MB/s]
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: logs/lightning_logs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name  | Type       | Params
# -------------------------------------
# 0 | model | CasafariNN | 109 M
# -------------------------------------
# 15.4 K    Trainable params
# 109 M     Non-trainable params
# 109 M     Total params
# 438.007   Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Downloading: 100% 363/363 [00:00<00:00, 408kB/s]
#
# Downloading:   0% 0.00/226k [00:00<?, ?B/s]
# Downloading:  16% 36.0k/226k [00:00<00:00, 299kB/s]
# Downloading: 100% 226k/226k [00:00<00:00, 929kB/s]
#
# Downloading:   0% 0.00/455k [00:00<?, ?B/s]
# ...
